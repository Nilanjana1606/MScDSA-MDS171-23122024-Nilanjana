# %% [markdown]
# Matrix Multiplication
#
# Jeeva, a mathematical expert, is looking for an expert in programming who can assist him in creating a Python program for Matrix Multiplication.
#
# His program has specific requirements.
#
# The matrices have to be saved inside a dictionary.
# The keys allowed in the dictionary are [matrix 1, matrix 2, result matrix]
# The values for the elements in the rows of the matrix have to be saved in the form of a list of lists [[row1][row2]].
# You must have functions for collecting the matrix and store in the dictionary.
# Another function to Process the matrix and store it in the dictionary.
# Another function to Display the result in a file, properly formatted.
# Menu option to show enter matrix 1, matrix 2, calculate, export to file. If the matrix has been entered, then it should take confirmation from the user before taking the input for matrix 1 or 2 again.

# %%
matrix1=[]
matrix2=[]
result_matrix=[[]]
matrix={"MATRIX 1":matrix1,
        "MATRIX 2": matrix2,
        "RESULT ": result_matrix}
row_no1=row_no2=col_no1=col_no2=0

row_no1=int(input("Enter the number of rows in matrix 1 : "))
col_no1=int(input("Enter the number of columns in matrix 1 : "))
row_no2=int(input("Enter the number of rows in matrix 2 : "))
col_no2=int(input("Enter the number of columns in matrix 2 : "))


def matrix_multiplication(A,B):
   

   # Initialize a result matrix with zeros
   result_matrix = [[0 for _for in range(col_no2)] for _ in range(row_no1)]
   
# Perform matrix multiplication
   for i in range(row_no1):
     for j in range(col_no2):
        for n in range(col_no1):
            result_matrix[i][j] += A[i][n] * B[n][j]

   return result_matrix


def matrix_result_display(A,B):
   matrix["MATRIX 1"]=A
   matrix["MATRIX 2"]=B
   matrix["RESULT"]=matrix_multiplication(A,B)
   for i in matrix.items():
      print(i)

print("Options:")
print("1. Enter the values for the matrices")
print("2. matrix multiplication")
print("3. display")
print("4. exit")
print("_"*50)
print("\n\n")
while True:
    
     choice = input("Enter your choice: ")
   
     print("choice entered : ", choice)
     print("\n")
     if choice == "1":
        if col_no1==row_no2:
           print("Matrix multiplication is possible ")

           for i in range(row_no1):
             row = []
             for j in range(col_no1):
                element = int(input(f"Enter element at position ({i+1},{j+1}): "))
                row.append(element)
             matrix1.append(row)

           

           for i in range(row_no2):
              row = []
              for j in range(col_no2):
                element = int(input(f"Enter element at position ({i+1},{j+1}): "))
                row.append(element)
              matrix2.append(row)

        else:

           print("Marix multiplication is not possible..")


        print("_"*50)

     elif choice == "2":
        matrix_multiplication(matrix1,matrix2)
        print("_"*50)
     elif choice == "3":
        matrix_result_display(matrix1,matrix2)
        print("_"* 50)
     elif choice=="4":
        break
     else:
       print("invalid option ")
