# %% [markdown]
# CAC-02
#
# # DOMAIN : HEALTHCARE SYSTEM IN LAVASA
#
#
# TARGET POPULATION : STUDENTS OF CHRIST UNIVERSITY
#
# **BACKGROUND:**
# Christ University,Lavasa (Pune Off Campus) is located admist the blanket of lush green mountains as well as the mesmerizing Lavasa lake. Many students from all parts of the country come to study in this place every year. Since it is a hilly region, the climate and temperature is not so normal as the different parts of the country.
#
# Here we want are trying to find out whether the medical facilties available in this remote place is enough to treat any kind of mdecial emergency faced by the students.
#
# METHODOLOGY:
# We shall perform exploratory data analysis to visualize and infer the reactions and statements made by the students to describe the health facilities available in this place.
#
#  The following are the steps to perform EDA:
#  1) IMPORTING PYTHON LIBRARIES
#  2) READING THE DATASET
#  3) ANALYZING THE DATA
#  4) CHECK FOR DUPLICATION
#  5) ANALYZING MISSING VALUES
#  6) DATA REDUCTION
#  7) DATA CLEANING
#  8) EDA UNIVARIATE ANALYSIS
#  9) EDA BIVARIATE ANALYSIS
#  10) STATISTICAL SUMMARY

# %% [markdown]
# IMPORTING PYTHON LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
import warnings
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")

# %% [markdown]
# READING THE DATASET

# %%
#cac1=pd.read_csv("HEALTHCARE IN LAVASA (Responses) - Form Responses 1.csv")
cac=pd.read_csv("D:\Telegram Desktop\MScDSA-MDS171-23122024-Nilanjana\CAC-2.csv")


cac
# Out:
#                                   COLLEGE EMAIL ID                  NAME  \
# 0         nandhana.rajeev@msds.christuniversity.in      Nandhana Rajeev
# 1               stuty.das@msds.christuniversity.in             Stuty Das
# 2    debolina.chatterjee@msds.christuniversity.in   Debolina Chatterjee
# 3                 yashi.s@msds.christuniversity.in                 yashi
# 4        trikalagga.saha@msds.christuniversity.in       Trikalagga Saha
# ..                                             ...                   ...
# 369                        rutujagalkar4@gmail.com         Rutuja Galkar
# 370                  naveenkrish19052000@gmail.com        Naveen Krishna
# 371                  fathimathulsusnaali@gmail.com  Fathima Thulsusnaali
# 372                             mubale00@gmail.com                Mubale
# 373                         shambhawi066@gmail.com             Shambhawi
#
#                      COURSE  YEAR  GENDER  \
# 0          MSC DATA SCIENCE     1  FEMALE
# ...

# %% [markdown]
# ANALYZING THE DATA :
# Here we want to check how many rows and columns the dataset have, information regarding each column,how many missing values are there and their data types.

# %%
# To show the top 5 observations of the dataset
cac.head()
# Out:
#                                 COLLEGE EMAIL ID                  NAME  \
# 0       nandhana.rajeev@msds.christuniversity.in      Nandhana Rajeev
# 1             stuty.das@msds.christuniversity.in             Stuty Das
# 2  debolina.chatterjee@msds.christuniversity.in   Debolina Chatterjee
# 3               yashi.s@msds.christuniversity.in                 yashi
# 4      trikalagga.saha@msds.christuniversity.in       Trikalagga Saha
#
#              COURSE  YEAR  GENDER  \
# 0  MSC DATA SCIENCE     1  FEMALE
# 1  MSC DATA SCIENCE     1  FEMALE
# 2  MSC DATA SCIENCE     1  FEMALE
# 3  MSC DATA SCIENCE     1  FEMALE
# 4  MSC DATA SCIENCE     1  FEMALE
#
#   DID YOU HAVE ANY HEALTH ISSUES BEFORE COMING TO LAVASA?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                YES
# 3                                                 NO
# 4                                                 NO
# ...

# %%
#To show the bottom 5 obseravtions of the dataset
cac.tail()
# Out:
#                   COLLEGE EMAIL ID                  NAME  \
# 369        rutujagalkar4@gmail.com         Rutuja Galkar
# 370  naveenkrish19052000@gmail.com        Naveen Krishna
# 371  fathimathulsusnaali@gmail.com  Fathima Thulsusnaali
# 372             mubale00@gmail.com                Mubale
# 373         shambhawi066@gmail.com             Shambhawi
#
#                      COURSE  YEAR  GENDER  \
# 369                  BA LLB     1  FEMALE
# 370        MSC DATA SCIENCE     1  FEMALE
# 371        MSC DATA SCIENCE     1  FEMALE
# 372                     MBA     2    MALE
# 373  BBA BUSINESS ANALYTICS     1    MALE
#
#     DID YOU HAVE ANY HEALTH ISSUES BEFORE COMING TO LAVASA?  \
# 369                                                YES
# 370                                                YES
# 371                                                 NO
# 372                                                 NO
# 373                                                 NO
#
# ...

# %%
# To get the information about each column of the dataset
cac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 16 columns):
#  #   Column                                                                   Non-Null Count  Dtype
# ---  ------                                                                   --------------  -----
#  0   COLLEGE EMAIL ID                                                         374 non-null    object
#  1   NAME                                                                     374 non-null    object
#  2   COURSE                                                                   374 non-null    object
#  3   YEAR                                                                     374 non-null    int64
#  4   GENDER                                                                   374 non-null    object
#  5   DID YOU HAVE ANY HEALTH ISSUES BEFORE COMING TO LAVASA?                  374 non-null    object
# ...

# %%
#WE CALCULATE THE NUMBER OF ROWS AND COLUMNS IN THE DATASET
cac.shape
# Out:
# (374, 16)

# %% [markdown]
# DATA CLEANING :
#
# We have to clean the data for further analysis. The following are the ways we can clean our data to proceed further:
# 1) Removing unwanted columns.
# 2) Replacing or emoving the missing values according to requirement
# 3) Removing duplicates from the data

# %%
#Checking for the no. of missing Values each column has.
# The yellow portion shows the missing values
sns.heatmap(cac.isnull(),cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
# percentage of missing values each has 
(cac.isnull().sum()/(len(cac)))*100
# Out:
# COLLEGE EMAIL ID                                                            0.000000
# NAME                                                                        0.000000
# COURSE                                                                      0.000000
# YEAR                                                                        0.000000
# GENDER                                                                      0.000000
# DID YOU HAVE ANY HEALTH ISSUES BEFORE COMING TO LAVASA?                     0.000000
# IF YES, PLEASE MENTION IT.                                                 91.443850
# DID YOU HAVE ANY HEALTH ISSUES AFTER COMING TO LAVASA ?                     0.000000
# IF YES, PLEASE MENTION IT..1                                               61.764706
# HOW DID YOU TREAT YOUR HEALTH ISSUES?                                       0.000000
# AVAILABILITY OF MEDICINES AT LAVASA                                         0.000000
# ...

# %%
# to check the datatypes of each column
cac.dtypes
# Out:
# COLLEGE EMAIL ID                                                           object
# NAME                                                                       object
# COURSE                                                                     object
# YEAR                                                                        int64
# GENDER                                                                     object
# DID YOU HAVE ANY HEALTH ISSUES BEFORE COMING TO LAVASA?                    object
# IF YES, PLEASE MENTION IT.                                                 object
# DID YOU HAVE ANY HEALTH ISSUES AFTER COMING TO LAVASA ?                    object
# IF YES, PLEASE MENTION IT..1                                               object
# HOW DID YOU TREAT YOUR HEALTH ISSUES?                                      object
# AVAILABILITY OF MEDICINES AT LAVASA                                        object
# ...

# %%
# To check the no. of duplicate values each column has

dups = cac.pivot_table(index = ['NAME'], aggfunc ='size') 
dups
# Out:
# NAME
#  Riya Das                1
# ARUSHI SHARMA            1
# AS                       1
# Aadith Joseph Mathew     1
# Aadya Kapoor             1
#                         ..
# bhavya sree              1
# ch.vishnupriya           1
# sarnalika paul           1
# sudiksha sharma          1
# yashi                    1
# Length: 354, dtype: int64

# %%
# We are removing the columns that are not required in the dataset
cac = cac.drop(['Timestamp'], axis = 1)
cac = cac.drop(['ANY SUGGESTIONS IF YOU LIKE TO IMPROVE THE MEDICAL FACILITIES IN LAVASA'], axis = 1)

cac.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\NILANJANA\OneDrive\Desktop\CAC2.ipynb Cell 16 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/NILANJANA/OneDrive/Desktop/CAC2.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> # We are removing the columns that are not required in the dataset
# ----> <a href='vscode-notebook-cell:/c%3A/Users/NILANJANA/OneDrive/Desktop/CAC2.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a> cac = cac.drop(['Timestamp'], axis = 1)
#       <a href='vscode-notebook-cell:/c%3A/Users/NILANJANA/OneDrive/Desktop/CAC2.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> cac = cac.drop(['ANY SUGGESTIONS IF YOU LIKE TO IMPROVE THE MEDICAL FACILITIES IN LAVASA'], axis = 1)
#       <a href='vscode-notebook-cell:/c%3A/Users/NILANJANA/OneDrive/Desktop/CAC2.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> cac.info()
#
# ...

# %%
df=cac.drop_duplicates(keep='last')
df
# Out:
#                                   COLLEGE EMAIL ID                  NAME  \
# 0         nandhana.rajeev@msds.christuniversity.in      Nandhana Rajeev
# 1               stuty.das@msds.christuniversity.in             Stuty Das
# 2    debolina.chatterjee@msds.christuniversity.in   Debolina Chatterjee
# 3                 yashi.s@msds.christuniversity.in                 yashi
# 5           jyosna.philip@msds.christuniversity.in         Jyosna philip
# ..                                             ...                   ...
# 369                        rutujagalkar4@gmail.com         Rutuja Galkar
# 370                  naveenkrish19052002@gmail.com        Naveen Krishna
# 371                  fathimathulsusnaali@gmail.com  Fathima Thulsusnaali
# 372                             mubale02@gmail.com                Mubale
# 373                         shambhawi066@gmail.com             Shambhawi
#
#                COURSE YEAR  GENDER  \
# 0    MSC DATA SCIENCE    1  FEMALE
# ...

# %%
# filling up the NaN values in the different columns

cac['HOW DID YOU TREAT YOUR HEALTH ISSUES?'] = cac['HOW DID YOU TREAT YOUR HEALTH ISSUES?'].fillna('OTHER')
cac['HOW MANY TIMES DID YOU VISIT THE HOSPITAL ?'] = cac['HOW MANY TIMES DID YOU VISIT THE HOSPITAL ?'].fillna('DID NOT VISIT')
cac['WHICH TREATMENT WAS MOST EFFECTIVE ?']=cac["WHICH TREATMENT WAS MOST EFFECTIVE ?"].fillna('OTHER')
cac['COST OF TREATMENT'] = cac['COST OF TREATMENT'].fillna('0')

cac.isnull().sum()

# we have filled up most the missing values in the important columns we shall further use for analysis
# Out:
# COLLEGE EMAIL ID                                             0
# NAME                                                         0
# COURSE                                                       0
# YEAR                                                         2
# GENDER                                                       0
# DID YOU HAVE ANY HEALTH ISSUES BEFORE COMING TO LAVASA?      0
# IF YES, PLEASE MENTION IT.                                 342
# DID YOU HAVE ANY HEALTH ISSUES AFTER COMING TO LAVASA ?      0
# IF YES, PLEASE MENTION IT..1                               231
# HOW DID YOU TREAT YOUR HEALTH ISSUES?                        0
# AVAILABILITY OF MEDICINES AT LAVASA                          6
# HOW MANY TIMES DID YOU VISIT THE HOSPITAL ?                  0
# WHICH TREATMENT WAS MOST EFFECTIVE ?                         0
# COST OF TREATMENT                                            0
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .              0
# dtype: int64

# %% [markdown]
# EDA UNIVARIATE ANALYSIS
#
# We are trying to analyze each factor and since they are categorical we are trying to focus on their frequency of occurence.
# We shall also compare two factors and try to visualize by the following plots.

# %%
sns.set_theme(style="ticks") 

  
g = sns.catplot(x="GENDER", 
                kind="count", 
                data=cac)

# %%
sns.set_theme(style="ticks") 

  
g = sns.catplot(x="YEAR", 
                kind="count", 
                data=cac)

# %%
sns.set_theme(style="ticks") 

  
g = sns.catplot(y="COURSE", 
                kind="count", 
                data=cac)

# %%
sns.set_theme(style="ticks") 

  
g = sns.catplot(x="DID YOU HAVE ANY HEALTH ISSUES BEFORE COMING TO LAVASA?", 
                kind="count", 
                data=cac)

# %%
sns.set_theme(style="ticks") 

  
g = sns.catplot(x="DID YOU HAVE ANY HEALTH ISSUES AFTER COMING TO LAVASA ?", 
                kind="count", 
                data=cac)

# %%
# The given plot will compare two factors -> "GENDER" and "WHICH TREATMENT WAS MOST EFFECTIVE ?", filtered by "YEAR"
                                                                    


first_dimension = "GENDER"
horizontal_label = "COUNT"
second_dimension = "WHICH TREATMENT WAS MOST EFFECTIVE ?"
ax=sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=cac.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())
ax.legend(title=second_dimension, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# The

# %%
first_dimension = "GENDER"
horizontal_label = "COUNT"
second_dimension = "COST OF TREATMENT"
ax=sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=cac.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())

ax.legend(title=second_dimension, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# Treatment cost for most of the students is below 1000

# %%
import matplotlib.pyplot as plt

first_dimension = "GENDER"
horizontal_label = "COUNT"
second_dimension = "AVAILABILITY OF MEDICINES AT LAVASA"
ax= sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=cac.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())

ax.legend(title=second_dimension, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#medicines are fairly available

# %%
import matplotlib.pyplot as plt


first_dimension = "GENDER"
horizontal_label = "COUNT"
second_dimension = "HOW DID YOU TREAT YOUR HEALTH ISSUES?"
ax=sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=cac.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())

ax.legend(title=second_dimension, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

#Most of the students have opted for self treatment

# %%
import matplotlib.pyplot as plt

first_dimension = "GENDER"
horizontal_label = "COUNT"
second_dimension = "HOW MANY TIMES DID YOU VISIT THE HOSPITAL ?"
ax=sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=cac.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())

ax.legend(title=second_dimension, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

# Most of the students have visited the hospital once

# %%
import matplotlib.pyplot as plt


first_dimension = "GENDER"
horizontal_label = "COUNT"
second_dimension = "RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA ."
ax=sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=cac.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())

ax.legend(title=second_dimension, loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()


# Its mostly poor and average

# %% [markdown]
# **EDA BIVARIATE ANALYSIS**
#
#  In bivariate analysis we shall try to find whether any two factors from the given dataset are related in some way.
#
#  Since the factors are categorical in nature, the test we are using to check for the correlation between 2 factors is #Chi-square test.
#
# There will be two hypotheses:
#
# H0: The factors are not correlated
# vs.
# H1: The factors are correlated
#
# After applying Chi-square test, we calculate the p value. If the p-value < 0.05, we reject H0.

# %%
CrosstabResult=pd.crosstab(index=cac['AVAILABILITY OF MEDICINES AT LAVASA'],columns=cac['RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .'])
print(CrosstabResult)

# importing the required function
from scipy.stats import chi2_contingency

# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])


# Interpretation : Availablity of medicines and the rating of medical services is highly correlated because the p-value is quite less than 0.05. Also, after seeing previous charts of these two factors we can say that due to the poor availablity of the medicines in Lavasa affects the overall health services rating( which is mostly poor or average)
# Out:
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  AVERAGE  GOOD  POOR  \
# AVAILABILITY OF MEDICINES AT LAVASA
# AVAILABLE                                             26     9     8
# FAIRLY AVAILABLE                                      71    16    61
# NOT AVAILABLE                                         34     7    44
#
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  VERY GOOD  VERY POOR
# AVAILABILITY OF MEDICINES AT LAVASA
# AVAILABLE                                                1          9
# FAIRLY AVAILABLE                                         0         44
# NOT AVAILABLE                                            1         43
# The P-Value of the ChiSq Test is: 0.0017421872835935808

# %%
CrosstabResult=pd.crosstab(index=cac['DID YOU HAVE ANY HEALTH ISSUES AFTER COMING TO LAVASA ?'],columns=cac['RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .'])
print(CrosstabResult)

# importing the required function
from scipy.stats import chi2_contingency

# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
print('The p-Value of the ChiSq Test is:', ChiSqResult[1])

# Interpretation : The above 2 factors are not related since the p-value>0.05
# Out:
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .     AVERAGE  GOOD  POOR  \
# DID YOU HAVE ANY HEALTH ISSUES AFTER COMING TO ...
# NO                                                       72    19    61
# YES                                                      59    13    52
#
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .     VERY GOOD  VERY POOR
# DID YOU HAVE ANY HEALTH ISSUES AFTER COMING TO ...
# NO                                                          0         44
# YES                                                         2         52
# The p-Value of the ChiSq Test is: 0.2931233430333829

# %%
CrosstabResult=pd.crosstab(index=cac['COST OF TREATMENT'],columns=cac['RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .'])
print(CrosstabResult)

# importing the required function
from scipy.stats import chi2_contingency

# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
print('The p-Value of the ChiSq Test is:', ChiSqResult[1])

#Interpretation : The above 2 factors are not related since p-value>0.05
# Out:
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  AVERAGE  GOOD  POOR  \
# COST OF TREATMENT
# 1000-2000                                             13     2    12
# 2000-5000                                             13     0     6
# 500-1000                                              23     7    25
# ABOVE 5000                                             5     3     6
# BELOW 500                                             77    20    64
#
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  VERY GOOD  VERY POOR
# COST OF TREATMENT
# 1000-2000                                                0          7
# 2000-5000                                                0         12
# 500-1000                                                 0         23
# ABOVE 5000                                               0          8
# BELOW 500                                                2         46
# The p-Value of the ChiSq Test is: 0.5711957153023006

# %%
CrosstabResult=pd.crosstab(index=cac['WHICH TREATMENT WAS MOST EFFECTIVE ?'],columns=cac['RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .'])
print(CrosstabResult)

# importing the required function
from scipy.stats import chi2_contingency

# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])

#Interpretation : The above factorS are not related.
# Out:
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  AVERAGE  GOOD  POOR  \
# WHICH TREATMENT WAS MOST EFFECTIVE ?
# A. SELF TREATMENT                                     68    11    50
# B. STUDENT MEDICAL POINT                               7     5     6
# C. APOLLO HOSPITAL                                    19     3    16
# D. HOSPITALS IN PUNE                                  17     3    16
# E. OTHER                                              20    10    25
#
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  VERY GOOD  VERY POOR
# WHICH TREATMENT WAS MOST EFFECTIVE ?
# A. SELF TREATMENT                                        2         51
# B. STUDENT MEDICAL POINT                                 0          4
# C. APOLLO HOSPITAL                                       0          8
# D. HOSPITALS IN PUNE                                     0         14
# E. OTHER                                                 0         19
# The P-Value of the ChiSq Test is: 0.3866506288839453

# %%
CrosstabResult=pd.crosstab(index=cac['HOW MANY TIMES DID YOU VISIT THE HOSPITAL ?'],columns=cac['RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .'])
print(CrosstabResult)

# importing the required function
from scipy.stats import chi2_contingency

# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])

#Interpretation : The above 2 factors are not related
# Out:
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  AVERAGE  GOOD  POOR  \
# HOW MANY TIMES DID YOU VISIT THE HOSPITAL ?
# HAVE NOT VISITED                                      41    12    33
# MORE THAN ONCE                                        45     7    30
# ONCE                                                  45    12    50
# SELF TREATMENT                                         0     1     0
#
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  VERY GOOD  VERY POOR
# HOW MANY TIMES DID YOU VISIT THE HOSPITAL ?
# HAVE NOT VISITED                                         0         20
# MORE THAN ONCE                                           1         31
# ONCE                                                     1         45
# SELF TREATMENT                                           0          0
# The P-Value of the ChiSq Test is: 0.07622532753811194

# %%
CrosstabResult=pd.crosstab(index=cac['HOW DID YOU TREAT YOUR HEALTH ISSUES?'],columns=cac['RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .'])
print(CrosstabResult)

# importing the required function
from scipy.stats import chi2_contingency

# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])

#Interpretation : The above 2 factors are related. Most of the students opts for self-treatment, thats why they dont opt for any other medical facilties in Lavasa and that affects the rating.
# Out:
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  AVERAGE  GOOD  POOR  \
# HOW DID YOU TREAT YOUR HEALTH ISSUES?
# APOLLO HOSPITAL                                       28     3    25
# HOSPITALS IN PUNE                                     11     5     9
# MEDICAL POINT                                          3     0     0
# OTHER                                                 27     7    24
# SELF TREATMENT                                        45    13    43
# STUDENT MEDICAL POINT                                 17     4    12
#
# RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .  VERY GOOD  VERY POOR
# HOW DID YOU TREAT YOUR HEALTH ISSUES?
# APOLLO HOSPITAL                                          1          9
# HOSPITALS IN PUNE                                        0         13
# MEDICAL POINT                                            0          1
# OTHER                                                    0         15
# ...

# %%
# Assuming you have data loaded into 'cac' DataFrame
CrosstabResult = pd.crosstab(index=cac['AVAILABILITY OF MEDICINES AT LAVASA'], columns=cac['RATE THE MEDICAL SERVICES AVAILABLE IN LAVASA .'])

# Calculate the correlation between the two categorical variables
corr = CrosstabResult.corr()

# Create a correlation plot using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", linewidths=.5)
plt.title("Correlation Plot")
plt.show()

# %% [markdown]
# CONCLUSION : THE POOR AVAILABILITY OF MEDICINES IS THE FACTOR THAT REQUIRES OUR ATTENTION AND WE NEED TO STOCK UP MORE VARIETIES AND PROVIDE DISCOUNTS SO THAT STUDENTS CAN CONVINIENTLY USE THEM.
#
# THE APOLLO HOSPITAL CAN ALSO COLLABORATE WITH THE CHRIST UNIVERSITY TO BRING A GOOD AND EFFICIENT DOCTOR FOR THE STUDENTS ONCE IN A WEEK FOR BETTER TREATMENT. ALSO THEY SHOULD TAKE ORDER FOR DIFFERENT MEDICINES WHICH ARE COSTLY AND UNAVAILABLE SO THAT THEY CAN RESTOCK QUICKLY FOR THE CONVINIENCE OF THE STUDENTS.
